# %% [markdown]
# <a href="https://colab.research.google.com/github/sofi-blas/Entrega-Modulo1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Este es mi primer cuaderno
# Aqui voy a mezclar código MarkDown con operaciones matemáticas
#
#
# *  Suma
# *  Resta
# *  División
# *  Multiplicación

# %%
a=3
b=9
a+b
# Out:
# [1] 12

# %%
c=10
d=-8
d-c
# Out:
# [1] -18

# %%
a = 1:100
b = a^2
plot(a,b, main='presion del gas crítico',xlab='Volumen',ylab='presión',type='b',col='blue')
# Out:
# Plot with title “presion del gas crítico”
